# %%
# !apt update
# !echo Y | apt-get install libgl1-mesa-dev
# Out:
# Get:1 http://security.debian.org/debian-security bullseye-security InRelease [44.1 kB]
# Get:2 http://security.debian.org/debian-security bullseye-security/main amd64 Packages [76.2 kB]
# Get:3 http://deb.debian.org/debian bullseye InRelease [116 kB]33m0m
# Get:4 http://deb.debian.org/debian bullseye-updates InRelease [39.4 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 Packages [8180 kB]
# Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Packages [2592 B]
# Fetched 8458 kB in 5s (1594 kB/s)3m
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 1 package can be upgraded. Run 'apt list --upgradable' to see it.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libegl-dev libegl-mesa0 libegl1 libelf1 libgbm1 libgl-dev libgl1
#   libgl1-mesa-dri libglapi-mesa libgles-dev libgles1 libgles2 libglvnd-dev
#   libglvnd0 libglx-dev libglx-mesa0 libglx0 libllvm11 libopengl-dev libopengl0
#   libpciaccess0 libpthread-stubs0-dev libsensors-config libsensors5 libvulkan1
#   libwayland-client0 libwayland-server0 libx11-dev libx11-xcb1 libxau-dev
#   libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0
#   libxcb-shm0 libxcb-sync1 libxcb-xfixes0 libxcb1-dev libxdamage1 libxdmcp-dev
#   libxfixes3 libxshmfence1 libxxf86vm1 libz3-4 mesa-vulkan-drivers
#   x11proto-dev xorg-sgml-doctools xtrans-dev
# Suggested packages:
#   pciutils lm-sensors libx11-doc libxcb-doc
# The following NEW packages will be installed:
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libegl-dev libegl-mesa0 libegl1 libelf1 libgbm1 libgl-dev libgl1
#   libgl1-mesa-dev libgl1-mesa-dri libglapi-mesa libgles-dev libgles1 libgles2
#   libglvnd-dev libglvnd0 libglx-dev libglx-mesa0 libglx0 libllvm11
#   libopengl-dev libopengl0 libpciaccess0 libpthread-stubs0-dev
#   libsensors-config libsensors5 libvulkan1 libwayland-client0
#   libwayland-server0 libx11-dev libx11-xcb1 libxau-dev libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcb1-dev libxdamage1 libxdmcp-dev libxfixes3
#   libxshmfence1 libxxf86vm1 libz3-4 mesa-vulkan-drivers x11proto-dev
#   xorg-sgml-doctools xtrans-dev
# 0 upgraded, 56 newly installed, 0 to remove and 1 not upgraded.
# Need to get 43.2 MB of archives.
# After this operation, 178 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bullseye/main amd64 libdrm-common all 2.4.104-1 [14.9 kB]
# Get:2 http://deb.debian.org/debian bullseye/main amd64 libdrm2 amd64 2.4.104-1 [41.5 kB]
# Get:3 http://deb.debian.org/debian bullseye/main amd64 libdrm-amdgpu1 amd64 2.4.104-1 [28.5 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 libpciaccess0 amd64 0.16-1 [53.6 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 libdrm-intel1 amd64 2.4.104-1 [71.8 kB]
# Get:6 http://deb.debian.org/debian bullseye/main amd64 libdrm-nouveau2 amd64 2.4.104-1 [26.8 kB]
# Get:7 http://deb.debian.org/debian bullseye/main amd64 libdrm-radeon1 amd64 2.4.104-1 [30.2 kB]
# Get:8 http://deb.debian.org/debian bullseye/main amd64 libglvnd0 amd64 1.3.2-1 [53.6 kB]
# Get:9 http://deb.debian.org/debian bullseye/main amd64 libwayland-server0 amd64 1.18.0-2~exp1.1 [34.4 kB]
# Get:10 http://deb.debian.org/debian bullseye/main amd64 libgbm1 amd64 20.3.5-1 [73.5 kB]
# Get:11 http://deb.debian.org/debian bullseye/main amd64 libglapi-mesa amd64 20.3.5-1 [71.7 kB]
# Get:12 http://deb.debian.org/debian bullseye/main amd64 libwayland-client0 amd64 1.18.0-2~exp1.1 [26.9 kB]
# Get:13 http://deb.debian.org/debian bullseye/main amd64 libx11-xcb1 amd64 2:1.7.2-1 [203 kB]
# Get:14 http://deb.debian.org/debian bullseye/main amd64 libxcb-dri2-0 amd64 1.14-3 [103 kB]
# Get:15 http://deb.debian.org/debian bullseye/main amd64 libxcb-dri3-0 amd64 1.14-3 [102 kB]
# Get:16 http://deb.debian.org/debian bullseye/main amd64 libxcb-present0 amd64 1.14-3 [101 kB]
# Get:17 http://deb.debian.org/debian bullseye/main amd64 libxcb-sync1 amd64 1.14-3 [105 kB]
# Get:18 http://deb.debian.org/debian bullseye/main amd64 libxcb-xfixes0 amd64 1.14-3 [105 kB]
# Get:19 http://deb.debian.org/debian bullseye/main amd64 libxshmfence1 amd64 1.3-1 [8820 B]
# Get:20 http://deb.debian.org/debian bullseye/main amd64 libegl-mesa0 amd64 20.3.5-1 [141 kB]
# Get:21 http://deb.debian.org/debian bullseye/main amd64 libegl1 amd64 1.3.2-1 [34.8 kB]
# Get:22 http://deb.debian.org/debian bullseye/main amd64 libxcb-glx0 amd64 1.14-3 [118 kB]
# Get:23 http://deb.debian.org/debian bullseye/main amd64 libxcb-shm0 amd64 1.14-3 [101 kB]
# Get:24 http://deb.debian.org/debian bullseye/main amd64 libxdamage1 amd64 1:1.1.5-2 [15.7 kB]
# Get:25 http://deb.debian.org/debian bullseye/main amd64 libxfixes3 amd64 1:5.0.3-2 [22.1 kB]
# Get:26 http://deb.debian.org/debian bullseye/main amd64 libxxf86vm1 amd64 1:1.1.4-1+b2 [20.8 kB]
# Get:27 http://deb.debian.org/debian bullseye/main amd64 libelf1 amd64 0.183-1 [165 kB]
# Get:28 http://deb.debian.org/debian bullseye/main amd64 libz3-4 amd64 4.8.10-1 [6949 kB]
# Get:29 http://deb.debian.org/debian bullseye/main amd64 libllvm11 amd64 1:11.0.1-2 [17.9 MB]
# Get:30 http://deb.debian.org/debian bullseye/main amd64 libsensors-config all 1:3.6.0-7 [32.3 kB]
# Get:31 http://deb.debian.org/debian bullseye/main amd64 libsensors5 amd64 1:3.6.0-7 [52.3 kB]
# Get:32 http://deb.debian.org/debian bullseye/main amd64 libvulkan1 amd64 1.2.162.0-1 [103 kB]
# Get:33 http://deb.debian.org/debian bullseye/main amd64 libgl1-mesa-dri amd64 20.3.5-1 [9633 kB]
# Get:34 http://deb.debian.org/debian bullseye/main amd64 libglx-mesa0 amd64 20.3.5-1 [186 kB]
# Get:35 http://deb.debian.org/debian bullseye/main amd64 libglx0 amd64 1.3.2-1 [35.7 kB]
# Get:36 http://deb.debian.org/debian bullseye/main amd64 libgl1 amd64 1.3.2-1 [89.5 kB]
# Get:37 http://deb.debian.org/debian bullseye/main amd64 xorg-sgml-doctools all 1:1.11-1.1 [22.1 kB]
# Get:38 http://deb.debian.org/debian bullseye/main amd64 x11proto-dev all 2020.1-1 [594 kB]
# Get:39 http://deb.debian.org/debian bullseye/main amd64 libxau-dev amd64 1:1.0.9-1 [22.9 kB]
# Get:40 http://deb.debian.org/debian bullseye/main amd64 libxdmcp-dev amd64 1:1.1.2-3 [42.2 kB]
# Get:41 http://deb.debian.org/debian bullseye/main amd64 xtrans-dev all 1.4.0-1 [98.7 kB]
# Get:42 http://deb.debian.org/debian bullseye/main amd64 libpthread-stubs0-dev amd64 0.4-1 [5344 B]
# Get:43 http://deb.debian.org/debian bullseye/main amd64 libxcb1-dev amd64 1.14-3 [176 kB]
# Get:44 http://deb.debian.org/debian bullseye/main amd64 libx11-dev amd64 2:1.7.2-1 [841 kB]
# Get:45 http://deb.debian.org/debian bullseye/main amd64 libglx-dev amd64 1.3.2-1 [16.3 kB]
# Get:46 http://deb.debian.org/debian bullseye/main amd64 libgl-dev amd64 1.3.2-1 [100 kB]
# Get:47 http://deb.debian.org/debian bullseye/main amd64 libegl-dev amd64 1.3.2-1 [19.6 kB]
# Get:48 http://deb.debian.org/debian bullseye/main amd64 libgles1 amd64 1.3.2-1 [12.6 kB]
# Get:49 http://deb.debian.org/debian bullseye/main amd64 libgles2 amd64 1.3.2-1 [17.7 kB]
# Get:50 http://deb.debian.org/debian bullseye/main amd64 libgles-dev amd64 1.3.2-1 [50.3 kB]
# Get:51 http://deb.debian.org/debian bullseye/main amd64 libopengl0 amd64 1.3.2-1 [31.5 kB]
# Get:52 http://deb.debian.org/debian bullseye/main amd64 libopengl-dev amd64 1.3.2-1 [5876 B]
# Get:53 http://deb.debian.org/debian bullseye/main amd64 libglvnd-dev amd64 1.3.2-1 [13.9 kB]
# Get:54 http://deb.debian.org/debian bullseye/main amd64 libgl1-mesa-dev amd64 20.3.5-1 [51.1 kB]
# Get:55 http://deb.debian.org/debian bullseye/main amd64 libxcb-randr0 amd64 1.14-3 [113 kB]
# Get:56 http://deb.debian.org/debian bullseye/main amd64 mesa-vulkan-drivers amd64 20.3.5-1 [4086 kB]
# Fetched 43.2 MB in 6s (6667 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libdrm-common.
# (Reading database ... 12434 files and directories currently installed.)
# Preparing to unpack .../00-libdrm-common_2.4.104-1_all.deb ...
# Unpacking libdrm-common (2.4.104-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../01-libdrm2_2.4.104-1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.104-1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../02-libdrm-amdgpu1_2.4.104-1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.104-1) ...
# Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../03-libpciaccess0_0.16-1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.16-1) ...
# Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../04-libdrm-intel1_2.4.104-1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.104-1) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../05-libdrm-nouveau2_2.4.104-1_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.104-1) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../06-libdrm-radeon1_2.4.104-1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.104-1) ...
# Selecting previously unselected package libglvnd0:amd64.
# Preparing to unpack .../07-libglvnd0_1.3.2-1_amd64.deb ...
# Unpacking libglvnd0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../08-libwayland-server0_1.18.0-2~exp1.1_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.18.0-2~exp1.1) ...
# Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../09-libgbm1_20.3.5-1_amd64.deb ...
# Unpacking libgbm1:amd64 (20.3.5-1) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../10-libglapi-mesa_20.3.5-1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (20.3.5-1) ...
# Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../11-libwayland-client0_1.18.0-2~exp1.1_amd64.deb ...
# Unpacking libwayland-client0:amd64 (1.18.0-2~exp1.1) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../12-libx11-xcb1_2%3a1.7.2-1_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.7.2-1) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../13-libxcb-dri2-0_1.14-3_amd64.deb ...
# Unpacking libxcb-dri2-0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../14-libxcb-dri3-0_1.14-3_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../15-libxcb-present0_1.14-3_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../16-libxcb-sync1_1.14-3_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../17-libxcb-xfixes0_1.14-3_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.14-3) ...
# Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../18-libxshmfence1_1.3-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.3-1) ...
# Selecting previously unselected package libegl-mesa0:amd64.
# Preparing to unpack .../19-libegl-mesa0_20.3.5-1_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (20.3.5-1) ...
# Selecting previously unselected package libegl1:amd64.
# Preparing to unpack .../20-libegl1_1.3.2-1_amd64.deb ...
# Unpacking libegl1:amd64 (1.3.2-1) ...
# Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../21-libxcb-glx0_1.14-3_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../22-libxcb-shm0_1.14-3_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.14-3) ...
# Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../23-libxdamage1_1%3a1.1.5-2_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.5-2) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../24-libxfixes3_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../25-libxxf86vm1_1%3a1.1.4-1+b2_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../26-libelf1_0.183-1_amd64.deb ...
# Unpacking libelf1:amd64 (0.183-1) ...
# Selecting previously unselected package libz3-4:amd64.
# Preparing to unpack .../27-libz3-4_4.8.10-1_amd64.deb ...
# Unpacking libz3-4:amd64 (4.8.10-1) ...
# Selecting previously unselected package libllvm11:amd64.
# Preparing to unpack .../28-libllvm11_1%3a11.0.1-2_amd64.deb ...
# Unpacking libllvm11:amd64 (1:11.0.1-2) ...
# Selecting previously unselected package libsensors-config.
# Preparing to unpack .../29-libsensors-config_1%3a3.6.0-7_all.deb ...
# Unpacking libsensors-config (1:3.6.0-7) ...
# Selecting previously unselected package libsensors5:amd64.
# Preparing to unpack .../30-libsensors5_1%3a3.6.0-7_amd64.deb ...
# Unpacking libsensors5:amd64 (1:3.6.0-7) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../31-libvulkan1_1.2.162.0-1_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.2.162.0-1) ...
# Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../32-libgl1-mesa-dri_20.3.5-1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (20.3.5-1) ...
# Selecting previously unselected package libglx-mesa0:amd64.
# Preparing to unpack .../33-libglx-mesa0_20.3.5-1_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (20.3.5-1) ...
# Selecting previously unselected package libglx0:amd64.
# Preparing to unpack .../34-libglx0_1.3.2-1_amd64.deb ...
# Unpacking libglx0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgl1:amd64.
# Preparing to unpack .../35-libgl1_1.3.2-1_amd64.deb ...
# Unpacking libgl1:amd64 (1.3.2-1) ...
# Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../36-xorg-sgml-doctools_1%3a1.11-1.1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1.1) ...
# Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../37-x11proto-dev_2020.1-1_all.deb ...
# Unpacking x11proto-dev (2020.1-1) ...
# Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../38-libxau-dev_1%3a1.0.9-1_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.9-1) ...
# Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../39-libxdmcp-dev_1%3a1.1.2-3_amd64.deb ...
# Unpacking libxdmcp-dev:amd64 (1:1.1.2-3) ...
# Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../40-xtrans-dev_1.4.0-1_all.deb ...
# Unpacking xtrans-dev (1.4.0-1) ...
# Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../41-libpthread-stubs0-dev_0.4-1_amd64.deb ...
# Unpacking libpthread-stubs0-dev:amd64 (0.4-1) ...
# Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../42-libxcb1-dev_1.14-3_amd64.deb ...
# Unpacking libxcb1-dev:amd64 (1.14-3) ...
# Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../43-libx11-dev_2%3a1.7.2-1_amd64.deb ...
# Unpacking libx11-dev:amd64 (2:1.7.2-1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../44-libglx-dev_1.3.2-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../45-libgl-dev_1.3.2-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.3.2-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../46-libegl-dev_1.3.2-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../47-libgles1_1.3.2-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgles2:amd64.
# Preparing to unpack .../48-libgles2_1.3.2-1_amd64.deb ...
# Unpacking libgles2:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../49-libgles-dev_1.3.2-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.3.2-1) ...
# Selecting previously unselected package libopengl0:amd64.
# Preparing to unpack .../50-libopengl0_1.3.2-1_amd64.deb ...
# Unpacking libopengl0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../51-libopengl-dev_1.3.2-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.3.2-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../52-libglvnd-dev_1.3.2-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../53-libgl1-mesa-dev_20.3.5-1_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (20.3.5-1) ...
# Selecting previously unselected package libxcb-randr0:amd64.
# Preparing to unpack .../54-libxcb-randr0_1.14-3_amd64.deb ...
# Unpacking libxcb-randr0:amd64 (1.14-3) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../55-mesa-vulkan-drivers_20.3.5-1_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (20.3.5-1) ...
# Setting up libxcb-dri3-0:amd64 (1.14-3) ...
# Setting up libwayland-server0:amd64 (1.18.0-2~exp1.1) ...
# Setting up libx11-xcb1:amd64 (2:1.7.2-1) ...
# Setting up libpciaccess0:amd64 (0.16-1) ...
# Setting up libxdamage1:amd64 (1:1.1.5-2) ...
# Setting up libxcb-xfixes0:amd64 (1.14-3) ...
# Setting up libglvnd0:amd64 (1.3.2-1) ...
# Setting up libxcb-glx0:amd64 (1.14-3) ...
# Setting up libsensors-config (1:3.6.0-7) ...
# Setting up libxcb-shm0:amd64 (1.14-3) ...
# Setting up libpthread-stubs0-dev:amd64 (0.4-1) ...
# Setting up libopengl0:amd64 (1.3.2-1) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# Setting up libxcb-present0:amd64 (1.14-3) ...
# Setting up xtrans-dev (1.4.0-1) ...
# Setting up libz3-4:amd64 (4.8.10-1) ...
# Setting up libllvm11:amd64 (1:11.0.1-2) ...
# Setting up libgles2:amd64 (1.3.2-1) ...
# Setting up libxfixes3:amd64 (1:5.0.3-2) ...
# Setting up libxcb-sync1:amd64 (1.14-3) ...
# Setting up libgles1:amd64 (1.3.2-1) ...
# Setting up libsensors5:amd64 (1:3.6.0-7) ...
# Setting up libglapi-mesa:amd64 (20.3.5-1) ...
# Setting up libvulkan1:amd64 (1.2.162.0-1) ...
# Setting up libxcb-dri2-0:amd64 (1.14-3) ...
# Setting up libxshmfence1:amd64 (1.3-1) ...
# Setting up libxcb-randr0:amd64 (1.14-3) ...
# Setting up xorg-sgml-doctools (1:1.11-1.1) ...
# Setting up libopengl-dev:amd64 (1.3.2-1) ...
# Setting up libdrm-common (2.4.104-1) ...
# Setting up libelf1:amd64 (0.183-1) ...
# Setting up libwayland-client0:amd64 (1.18.0-2~exp1.1) ...
# Setting up x11proto-dev (2020.1-1) ...
# Setting up libxau-dev:amd64 (1:1.0.9-1) ...
# Setting up libxdmcp-dev:amd64 (1:1.1.2-3) ...
# Setting up libdrm2:amd64 (2.4.104-1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.104-1) ...
# Setting up mesa-vulkan-drivers:amd64 (20.3.5-1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.104-1) ...
# Setting up libxcb1-dev:amd64 (1.14-3) ...
# Setting up libgbm1:amd64 (20.3.5-1) ...
# Setting up libdrm-radeon1:amd64 (2.4.104-1) ...
# Setting up libdrm-intel1:amd64 (2.4.104-1) ...
# Setting up libgl1-mesa-dri:amd64 (20.3.5-1) ...
# Setting up libx11-dev:amd64 (2:1.7.2-1) ...
# Setting up libegl-mesa0:amd64 (20.3.5-1) ...
# Setting up libegl1:amd64 (1.3.2-1) ...
# Setting up libglx-mesa0:amd64 (20.3.5-1) ...
# Setting up libglx0:amd64 (1.3.2-1) ...
# Setting up libgl1:amd64 (1.3.2-1) ...
# Setting up libglx-dev:amd64 (1.3.2-1) ...
# Setting up libgl-dev:amd64 (1.3.2-1) ...
# Setting up libegl-dev:amd64 (1.3.2-1) ...
# Setting up libgles-dev:amd64 (1.3.2-1) ...
# Setting up libglvnd-dev:amd64 (1.3.2-1) ...
# Setting up libgl1-mesa-dev:amd64 (20.3.5-1) ...
# Processing triggers for libc-bin (2.31-13+deb11u2) ...

# %%
import os
import gym
import numpy as np
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
from stable_baselines3.common.vec_env import VecFrameStack, VecVideoRecorder, DummyVecEnv
from stable_baselines3 import A2C, DQN

log_dir = "./logs/"
os.makedirs(log_dir, exist_ok=True)
save_dir = "./tmp/gym"
os.makedirs(save_dir, exist_ok=True)
env_id = 'BreakoutNoFrameskip-v4'

monitor_kwargs = {'allow_early_resets':True}
env = make_atari_env(
    env_id, seed=2937996057, monitor_dir=log_dir, monitor_kwargs=monitor_kwargs
)
env.reset()
checkpoint_callback = CheckpointCallback(save_freq=1e5, save_path='./logs/')

model = DQN(
    policy='CnnPolicy', env=env, learning_rate=0.0001, buffer_size=100000,
    learning_starts=100000, batch_size=32, tau=1.0, gamma=0.99, train_freq=4,
    gradient_steps=1, replay_buffer_class=None, replay_buffer_kwargs=None, 
    optimize_memory_usage=True, target_update_interval=1000, 
    exploration_fraction=0.1, exploration_initial_eps=1.0,
    exploration_final_eps=0.01, max_grad_norm=10, tensorboard_log='', 
    create_eval_env=False, policy_kwargs=None, verbose=1, seed=2937996057,
    device="auto", _init_setup_model=True
)
    
# total_timestepsを決める
model.learn(
    total_timesteps=1e5, callback=checkpoint_callback, log_interval=-1, 
    eval_env=None, eval_freq=10000, n_eval_episodes=5, tb_log_name="DQN",
    eval_log_path=None, reset_num_timesteps=True
)
#model.learn(total_timesteps=10000, callback=checkpoint_callback)

model.save(save_dir + "/breakout")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 1        |
# |    fps              | 215      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 23       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 2        |
# |    fps              | 252      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 3        |
# |    fps              | 72       |
# |    time_elapsed     | 1        |
# |    total timesteps  | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 80       |
# |    time_elapsed     | 2        |
# |    total timesteps  | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 5        |
# |    fps              | 89       |
# |    time_elapsed     | 2        |
# |    total timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.97     |
# | time/               |          |
# |    episodes         | 6        |
# |    fps              | 129      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.967    |
# | time/               |          |
# |    episodes         | 7        |
# |    fps              | 134      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 330      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.965    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 139      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.963    |
# | time/               |          |
# |    episodes         | 9        |
# |    fps              | 144      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.961    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 148      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 11       |
# |    fps              | 152      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 418      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.956    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 135      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 441      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.954    |
# | time/               |          |
# |    episodes         | 13       |
# |    fps              | 139      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 464      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 853      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.938    |
# | time/               |          |
# |    episodes         | 14       |
# |    fps              | 171      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 629      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 975      |
# |    ep_rew_mean      | 2.67     |
# |    exploration rate | 0.933    |
# | time/               |          |
# |    episodes         | 15       |
# |    fps              | 177      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 680      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 975      |
# |    ep_rew_mean      | 2.67     |
# |    exploration rate | 0.93     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 181      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 975      |
# |    ep_rew_mean      | 2.67     |
# |    exploration rate | 0.928    |
# | time/               |          |
# |    episodes         | 17       |
# |    fps              | 183      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 724      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 975      |
# |    ep_rew_mean      | 2.67     |
# |    exploration rate | 0.921    |
# | time/               |          |
# |    episodes         | 18       |
# |    fps              | 169      |
# |    time_elapsed     | 4        |
# |    total timesteps  | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 975      |
# |    ep_rew_mean      | 2.67     |
# |    exploration rate | 0.919    |
# | time/               |          |
# |    episodes         | 19       |
# |    fps              | 172      |
# |    time_elapsed     | 4        |
# |    total timesteps  | 816      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | 2.25     |
# |    exploration rate | 0.917    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 173      |
# |    time_elapsed     | 4        |
# |    total timesteps  | 839      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | 2.25     |
# |    exploration rate | 0.915    |
# | time/               |          |
# |    episodes         | 21       |
# |    fps              | 176      |
# |    time_elapsed     | 4        |
# |    total timesteps  | 862      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | 2.25     |
# |    exploration rate | 0.912    |
# | time/               |          |
# |    episodes         | 22       |
# |    fps              | 178      |
# |    time_elapsed     | 4        |
# |    total timesteps  | 885      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | 2.25     |
# |    exploration rate | 0.91     |
# | time/               |          |
# |    episodes         | 23       |
# |    fps              | 181      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 908      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | 2.25     |
# |    exploration rate | 0.908    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 183      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 931      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 831      |
# |    ep_rew_mean      | 1.8      |
# |    exploration rate | 0.906    |
# | time/               |          |
# |    episodes         | 25       |
# |    fps              | 185      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 954      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 831      |
# |    ep_rew_mean      | 1.8      |
# |    exploration rate | 0.901    |
# | time/               |          |
# |    episodes         | 26       |
# |    fps              | 190      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 1005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 831      |
# |    ep_rew_mean      | 1.8      |
# |    exploration rate | 0.898    |
# | time/               |          |
# |    episodes         | 27       |
# |    fps              | 191      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 1026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 831      |
# |    ep_rew_mean      | 1.8      |
# |    exploration rate | 0.893    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 181      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 1078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 831      |
# |    ep_rew_mean      | 1.8      |
# |    exploration rate | 0.891    |
# | time/               |          |
# |    episodes         | 29       |
# |    fps              | 183      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 1101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.889    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 185      |
# |    time_elapsed     | 6        |
# |    total timesteps  | 1124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.884    |
# | time/               |          |
# |    episodes         | 31       |
# |    fps              | 190      |
# |    time_elapsed     | 6        |
# |    total timesteps  | 1176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.881    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 192      |
# |    time_elapsed     | 6        |
# |    total timesteps  | 1199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.879    |
# | time/               |          |
# |    episodes         | 33       |
# |    fps              | 193      |
# |    time_elapsed     | 6        |
# |    total timesteps  | 1220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.877    |
# | time/               |          |
# |    episodes         | 34       |
# |    fps              | 194      |
# |    time_elapsed     | 6        |
# |    total timesteps  | 1241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 873      |
# |    ep_rew_mean      | 2.14     |
# |    exploration rate | 0.861    |
# | time/               |          |
# |    episodes         | 35       |
# |    fps              | 198      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 873      |
# |    ep_rew_mean      | 2.14     |
# |    exploration rate | 0.858    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 200      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 873      |
# |    ep_rew_mean      | 2.14     |
# |    exploration rate | 0.856    |
# | time/               |          |
# |    episodes         | 37       |
# |    fps              | 201      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 873      |
# |    ep_rew_mean      | 2.14     |
# |    exploration rate | 0.854    |
# | time/               |          |
# |    episodes         | 38       |
# |    fps              | 203      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 873      |
# |    ep_rew_mean      | 2.14     |
# |    exploration rate | 0.852    |
# | time/               |          |
# |    episodes         | 39       |
# |    fps              | 204      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 828      |
# |    ep_rew_mean      | 1.88     |
# |    exploration rate | 0.849    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 205      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 828      |
# |    ep_rew_mean      | 1.88     |
# |    exploration rate | 0.847    |
# | time/               |          |
# |    episodes         | 41       |
# |    fps              | 207      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 828      |
# |    ep_rew_mean      | 1.88     |
# |    exploration rate | 0.84     |
# | time/               |          |
# |    episodes         | 42       |
# |    fps              | 212      |
# |    time_elapsed     | 7        |
# |    total timesteps  | 1613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 828      |
# |    ep_rew_mean      | 1.88     |
# |    exploration rate | 0.838    |
# | time/               |          |
# |    episodes         | 43       |
# |    fps              | 203      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 828      |
# |    ep_rew_mean      | 1.88     |
# |    exploration rate | 0.836    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 204      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.78     |
# |    exploration rate | 0.834    |
# | time/               |          |
# |    episodes         | 45       |
# |    fps              | 204      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.78     |
# |    exploration rate | 0.824    |
# | time/               |          |
# |    episodes         | 46       |
# |    fps              | 211      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.78     |
# |    exploration rate | 0.822    |
# | time/               |          |
# |    episodes         | 47       |
# |    fps              | 212      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.78     |
# |    exploration rate | 0.819    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 214      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.78     |
# |    exploration rate | 0.808    |
# | time/               |          |
# |    episodes         | 49       |
# |    fps              | 222      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 852      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.805    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 223      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 1966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 852      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.796    |
# | time/               |          |
# |    episodes         | 51       |
# |    fps              | 229      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 852      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.784    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 236      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 852      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.782    |
# | time/               |          |
# |    episodes         | 53       |
# |    fps              | 237      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 852      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.775    |
# | time/               |          |
# |    episodes         | 54       |
# |    fps              | 241      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.767    |
# | time/               |          |
# |    episodes         | 55       |
# |    fps              | 243      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.765    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 244      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.763    |
# | time/               |          |
# |    episodes         | 57       |
# |    fps              | 245      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 2395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.751    |
# | time/               |          |
# |    episodes         | 58       |
# |    fps              | 251      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.749    |
# | time/               |          |
# |    episodes         | 59       |
# |    fps              | 251      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 920      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.746    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 252      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 920      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.744    |
# | time/               |          |
# |    episodes         | 61       |
# |    fps              | 253      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 920      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.742    |
# | time/               |          |
# |    episodes         | 62       |
# |    fps              | 254      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 920      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.74     |
# | time/               |          |
# |    episodes         | 63       |
# |    fps              | 251      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 920      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.737    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 252      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 911      |
# |    ep_rew_mean      | 2.31     |
# |    exploration rate | 0.728    |
# | time/               |          |
# |    episodes         | 65       |
# |    fps              | 257      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 911      |
# |    ep_rew_mean      | 2.31     |
# |    exploration rate | 0.726    |
# | time/               |          |
# |    episodes         | 66       |
# |    fps              | 257      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 911      |
# |    ep_rew_mean      | 2.31     |
# |    exploration rate | 0.716    |
# | time/               |          |
# |    episodes         | 67       |
# |    fps              | 262      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 911      |
# |    ep_rew_mean      | 2.31     |
# |    exploration rate | 0.711    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 264      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 2921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 911      |
# |    ep_rew_mean      | 2.31     |
# |    exploration rate | 0.709    |
# | time/               |          |
# |    episodes         | 69       |
# |    fps              | 265      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 2942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.706    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 264      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 2965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.704    |
# | time/               |          |
# |    episodes         | 71       |
# |    fps              | 262      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 2988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.693    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 267      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 3105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.691    |
# | time/               |          |
# |    episodes         | 73       |
# |    fps              | 268      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 3126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 2.36     |
# |    exploration rate | 0.688    |
# | time/               |          |
# |    episodes         | 74       |
# |    fps              | 268      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 3149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.686    |
# | time/               |          |
# |    episodes         | 75       |
# |    fps              | 269      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 3172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.684    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 267      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 3195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.681    |
# | time/               |          |
# |    episodes         | 77       |
# |    fps              | 268      |
# |    time_elapsed     | 11       |
# |    total timesteps  | 3218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.679    |
# | time/               |          |
# |    episodes         | 78       |
# |    fps              | 269      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 2.33     |
# |    exploration rate | 0.677    |
# | time/               |          |
# |    episodes         | 79       |
# |    fps              | 270      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 887      |
# |    ep_rew_mean      | 2.19     |
# |    exploration rate | 0.675    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 270      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 887      |
# |    ep_rew_mean      | 2.19     |
# |    exploration rate | 0.67     |
# | time/               |          |
# |    episodes         | 81       |
# |    fps              | 272      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 887      |
# |    ep_rew_mean      | 2.19     |
# |    exploration rate | 0.668    |
# | time/               |          |
# |    episodes         | 82       |
# |    fps              | 273      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 887      |
# |    ep_rew_mean      | 2.19     |
# |    exploration rate | 0.665    |
# | time/               |          |
# |    episodes         | 83       |
# |    fps              | 273      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 887      |
# |    ep_rew_mean      | 2.19     |
# |    exploration rate | 0.66     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 276      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 880      |
# |    ep_rew_mean      | 2.18     |
# |    exploration rate | 0.658    |
# | time/               |          |
# |    episodes         | 85       |
# |    fps              | 272      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 880      |
# |    ep_rew_mean      | 2.18     |
# |    exploration rate | 0.656    |
# | time/               |          |
# |    episodes         | 86       |
# |    fps              | 269      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3479     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 880      |
# |    ep_rew_mean      | 2.18     |
# |    exploration rate | 0.653    |
# | time/               |          |
# |    episodes         | 87       |
# |    fps              | 270      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 3502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 880      |
# |    ep_rew_mean      | 2.18     |
# |    exploration rate | 0.651    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 270      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 880      |
# |    ep_rew_mean      | 2.18     |
# |    exploration rate | 0.649    |
# | time/               |          |
# |    episodes         | 89       |
# |    fps              | 271      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 860      |
# |    ep_rew_mean      | 2.06     |
# |    exploration rate | 0.647    |
# | time/               |          |
# |    episodes         | 90       |
# |    fps              | 271      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 860      |
# |    ep_rew_mean      | 2.06     |
# |    exploration rate | 0.644    |
# | time/               |          |
# |    episodes         | 91       |
# |    fps              | 272      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 860      |
# |    ep_rew_mean      | 2.06     |
# |    exploration rate | 0.635    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 275      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 860      |
# |    ep_rew_mean      | 2.06     |
# |    exploration rate | 0.632    |
# | time/               |          |
# |    episodes         | 93       |
# |    fps              | 276      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 860      |
# |    ep_rew_mean      | 2.06     |
# |    exploration rate | 0.63     |
# | time/               |          |
# |    episodes         | 94       |
# |    fps              | 277      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 2.05     |
# |    exploration rate | 0.628    |
# | time/               |          |
# |    episodes         | 95       |
# |    fps              | 273      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 2.05     |
# |    exploration rate | 0.626    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 272      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 2.05     |
# |    exploration rate | 0.624    |
# | time/               |          |
# |    episodes         | 97       |
# |    fps              | 272      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 3801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 2.05     |
# |    exploration rate | 0.619    |
# | time/               |          |
# |    episodes         | 98       |
# |    fps              | 274      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 859      |
# |    ep_rew_mean      | 2.05     |
# |    exploration rate | 0.616    |
# | time/               |          |
# |    episodes         | 99       |
# |    fps              | 274      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.614    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 275      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.612    |
# | time/               |          |
# |    episodes         | 101      |
# |    fps              | 275      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.61     |
# | time/               |          |
# |    episodes         | 102      |
# |    fps              | 276      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.608    |
# | time/               |          |
# |    episodes         | 103      |
# |    fps              | 276      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | 2        |
# |    exploration rate | 0.605    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 277      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | 1.9      |
# |    exploration rate | 0.603    |
# | time/               |          |
# |    episodes         | 105      |
# |    fps              | 277      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | 1.9      |
# |    exploration rate | 0.601    |
# | time/               |          |
# |    episodes         | 106      |
# |    fps              | 277      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | 1.9      |
# |    exploration rate | 0.599    |
# | time/               |          |
# |    episodes         | 107      |
# |    fps              | 277      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | 1.9      |
# |    exploration rate | 0.592    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 279      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | 1.9      |
# |    exploration rate | 0.59     |
# | time/               |          |
# |    episodes         | 109      |
# |    fps              | 279      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 827      |
# |    ep_rew_mean      | 1.86     |
# |    exploration rate | 0.588    |
# | time/               |          |
# |    episodes         | 110      |
# |    fps              | 279      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 827      |
# |    ep_rew_mean      | 1.86     |
# |    exploration rate | 0.585    |
# | time/               |          |
# |    episodes         | 111      |
# |    fps              | 279      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 4189     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 827      |
# |    ep_rew_mean      | 1.86     |
# |    exploration rate | 0.583    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 280      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 827      |
# |    ep_rew_mean      | 1.86     |
# |    exploration rate | 0.581    |
# | time/               |          |
# |    episodes         | 113      |
# |    fps              | 280      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 827      |
# |    ep_rew_mean      | 1.86     |
# |    exploration rate | 0.576    |
# | time/               |          |
# |    episodes         | 114      |
# |    fps              | 281      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 818      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.574    |
# | time/               |          |
# |    episodes         | 115      |
# |    fps              | 282      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 818      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.572    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 282      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 818      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.569    |
# | time/               |          |
# |    episodes         | 117      |
# |    fps              | 282      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 818      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.563    |
# | time/               |          |
# |    episodes         | 118      |
# |    fps              | 285      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 818      |
# |    ep_rew_mean      | 1.83     |
# |    exploration rate | 0.56     |
# | time/               |          |
# |    episodes         | 119      |
# |    fps              | 285      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.79     |
# |    exploration rate | 0.558    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 285      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.79     |
# |    exploration rate | 0.551    |
# | time/               |          |
# |    episodes         | 121      |
# |    fps              | 287      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.79     |
# |    exploration rate | 0.549    |
# | time/               |          |
# |    episodes         | 122      |
# |    fps              | 288      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.79     |
# |    exploration rate | 0.547    |
# | time/               |          |
# |    episodes         | 123      |
# |    fps              | 288      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 1.79     |
# |    exploration rate | 0.545    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 288      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 4600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 809      |
# |    ep_rew_mean      | 1.76     |
# |    exploration rate | 0.542    |
# | time/               |          |
# |    episodes         | 125      |
# |    fps              | 288      |
# |    time_elapsed     | 16       |
# |    total timesteps  | 4623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# | time/               |          |
# |    episodes         | 181      |
# |    fps              | 300      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | 1.36     |
# |    exploration rate | 0.39     |
# | time/               |          |
# |    episodes         | 182      |
# |    fps              | 301      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | 1.36     |
# |    exploration rate | 0.38     |
# | time/               |          |
# |    episodes         | 183      |
# |    fps              | 303      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | 1.36     |
# |    exploration rate | 0.378    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 303      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.41     |
# |    exploration rate | 0.376    |
# | time/               |          |
# |    episodes         | 185      |
# |    fps              | 303      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.41     |
# |    exploration rate | 0.373    |
# | time/               |          |
# |    episodes         | 186      |
# |    fps              | 303      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.41     |
# |    exploration rate | 0.371    |
# | time/               |          |
# |    episodes         | 187      |
# |    fps              | 302      |
# |    time_elapsed     | 20       |
# |    total timesteps  | 6351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.41     |
# |    exploration rate | 0.364    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 303      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.41     |
# |    exploration rate | 0.357    |
# | time/               |          |
# |    episodes         | 189      |
# |    fps              | 305      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.45     |
# |    exploration rate | 0.35     |
# | time/               |          |
# |    episodes         | 190      |
# |    fps              | 305      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.45     |
# |    exploration rate | 0.341    |
# | time/               |          |
# |    episodes         | 191      |
# |    fps              | 307      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6661     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.45     |
# |    exploration rate | 0.338    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 307      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.45     |
# |    exploration rate | 0.336    |
# | time/               |          |
# |    episodes         | 193      |
# |    fps              | 307      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.45     |
# |    exploration rate | 0.334    |
# | time/               |          |
# |    episodes         | 194      |
# |    fps              | 307      |
# |    time_elapsed     | 21       |
# |    total timesteps  | 6724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 767      |
# |    ep_rew_mean      | 1.49     |
# |    exploration rate | 0.327    |
# | time/               |          |
# |    episodes         | 195      |
# |    fps              | 308      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 767      |
# |    ep_rew_mean      | 1.49     |
# |    exploration rate | 0.322    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 308      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 767      |
# |    ep_rew_mean      | 1.49     |
# |    exploration rate | 0.32     |
# | time/               |          |
# |    episodes         | 197      |
# |    fps              | 308      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 767      |
# |    ep_rew_mean      | 1.49     |
# |    exploration rate | 0.318    |
# | time/               |          |
# |    episodes         | 198      |
# |    fps              | 309      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 767      |
# |    ep_rew_mean      | 1.49     |
# |    exploration rate | 0.311    |
# | time/               |          |
# |    episodes         | 199      |
# |    fps              | 310      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | 1.5      |
# |    exploration rate | 0.308    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 309      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | 1.5      |
# |    exploration rate | 0.299    |
# | time/               |          |
# |    episodes         | 201      |
# |    fps              | 311      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 7084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | 1.5      |
# |    exploration rate | 0.292    |
# | time/               |          |
# |    episodes         | 202      |
# |    fps              | 312      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 7155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | 1.5      |
# |    exploration rate | 0.28     |
# | time/               |          |
# |    episodes         | 203      |
# |    fps              | 313      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | 1.5      |
# |    exploration rate | 0.277    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 313      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 784      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.275    |
# | time/               |          |
# |    episodes         | 205      |
# |    fps              | 313      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 784      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.273    |
# | time/               |          |
# |    episodes         | 206      |
# |    fps              | 313      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 784      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.271    |
# | time/               |          |
# |    episodes         | 207      |
# |    fps              | 313      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 784      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.261    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 315      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 784      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.259    |
# | time/               |          |
# |    episodes         | 209      |
# |    fps              | 315      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 785      |
# |    ep_rew_mean      | 1.6      |
# |    exploration rate | 0.257    |
# | time/               |          |
# |    episodes         | 210      |
# |    fps              | 314      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 785      |
# |    ep_rew_mean      | 1.6      |
# |    exploration rate | 0.25     |
# | time/               |          |
# |    episodes         | 211      |
# |    fps              | 315      |
# |    time_elapsed     | 23       |
# |    total timesteps  | 7576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 785      |
# |    ep_rew_mean      | 1.6      |
# |    exploration rate | 0.248    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 315      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 785      |
# |    ep_rew_mean      | 1.6      |
# |    exploration rate | 0.245    |
# | time/               |          |
# |    episodes         | 213      |
# |    fps              | 315      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 785      |
# |    ep_rew_mean      | 1.6      |
# |    exploration rate | 0.234    |
# | time/               |          |
# |    episodes         | 214      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 793      |
# |    ep_rew_mean      | 1.63     |
# |    exploration rate | 0.231    |
# | time/               |          |
# |    episodes         | 215      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 793      |
# |    ep_rew_mean      | 1.63     |
# |    exploration rate | 0.229    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 793      |
# |    ep_rew_mean      | 1.63     |
# |    exploration rate | 0.227    |
# | time/               |          |
# |    episodes         | 217      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 793      |
# |    ep_rew_mean      | 1.63     |
# |    exploration rate | 0.225    |
# | time/               |          |
# |    episodes         | 218      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 793      |
# |    ep_rew_mean      | 1.63     |
# |    exploration rate | 0.223    |
# | time/               |          |
# |    episodes         | 219      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 786      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.22     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 786      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.218    |
# | time/               |          |
# |    episodes         | 221      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 786      |
# |    ep_rew_mean      | 1.59     |
# |    exploration rate | 0.216    |
# | time/               |          |
# |    episodes         | 222      |
# |    fps              | 317      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 7921     |
# ----------------------------------

# %%
# Video Record
video_folder = './logs/videos'
monitor_kwargs = {'allow_early_resets':True}
wrapper_kwargs = {'noop_max':1}

env = make_atari_env(env_id, seed=293799605, wrapper_kwargs=wrapper_kwargs)
env = VecVideoRecorder(
    venv=env, video_folder=video_folder, record_video_trigger=lambda x : x == 0,
    video_length=np.inf, name_prefix='rl-video'
)

done = False
state = env.reset()
while not done:
    action, _ = model.predict(state)
    state, _, done, info = env.step(action)
env.close()
print("finished")
